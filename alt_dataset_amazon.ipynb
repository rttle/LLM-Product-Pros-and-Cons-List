# %% [markdown]
# ## Tensorflow Amazon Watch Reviews Dataset
# * https://www.tensorflow.org/datasets/catalog/amazon_us_reviews#amazon_us_reviewswatches_v1_00 (originally what I wanted to use, but access no longer available)
# * https://amazon-reviews-2023.github.io/
#     * Will use this dataset and filter down so that only watch reviews are left
# * This dataset was found as a failsafe to allow the LLM project to proceed within the limited timeframe
# * While the Watch U Seek reviews were successfully scraped, looking at the csv file shows extensive preprocessing would need to be done
#     * Clean up the text that was captured
#     * Remove reviews for watch related items (but not actual watch reviews)
#     * Remove reviews that are just links to video reviews
#     * Create a function to pull out the name of the watch model being reviewed (or manually do that for the 3501 reviews scraped)
# * Due to fulltime work obligations, I cannot dedicate that much time for this project; thus, I have included my notebooks showing my Watch U Seek scraper and glancing at the created dataset to show how this project could evolve given more time.

# %%
import pandas as pd
import numpy as np
import gzip
import json
import csv
from tqdm import tqdm

# %%
#checking categories to see how watches show up
with gzip.open('meta_Clothing_Shoes_and_Jewelry.jsonl.gz', "rt", encoding="utf-8") as f:
    for _ in range(100):
        product = json.loads(next(f))
        print(product.get("categories", []))
# Out:
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Swimsuits & Cover Ups', 'Cover-Ups']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Outdoor', 'Hiking & Trekking', 'Hiking Shoes']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals', 'Flats']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Women', 'Skirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Handbags & Wallets', 'Crossbody Bags']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Rings']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Loafers & Slip-Ons']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Boys', 'Accessories', 'Gloves & Mittens']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Dresses', 'Formal']
# ['Clothing, Shoes & Jewelry', 'Luggage & Travel Gear', 'Travel Accessories']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Dresses', 'Casual']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Active', 'Active Shorts']
# ['Clothing, Shoes & Jewelry', 'Men', 'Uniforms, Work & Safety', 'Clothing', 'Military']
# ['Clothing, Shoes & Jewelry', 'Girls', 'Jewelry', 'Earrings', 'Stud']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Active Pants', 'Sweatpants']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Lingerie, Sleep & Lounge', 'Lingerie', 'Bras', 'Everyday Bras']
# ['Clothing, Shoes & Jewelry', 'Girls', 'Clothing', 'Jackets & Coats', 'Jackets']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Athletic', 'Running', 'Road Running']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Active Shirts & Tees', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', 'Slippers']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Active Shorts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Tops, Tees & Blouses', 'Blouses & Button-Down Shirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Sweaters', 'Cardigans']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals', 'Flats']
# ['Clothing, Shoes & Jewelry', "Men's Watches Under $50"]
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Scarves & Wraps', 'Cold Weather Scarves & Wraps']
# ['Clothing, Shoes & Jewelry', 'Girls', 'Shoes', 'Athletic', 'Racquet Sports']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Tops, Tees & Blouses', 'Tanks & Camis']
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Hats & Caps']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Tops, Tees & Blouses', 'Blouses & Button-Down Shirts']
# ['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories', 'Shoe Care & Accessories', 'Shoelaces']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Earrings']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Lingerie, Sleep & Lounge', 'Lingerie', 'Panties', 'Briefs']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals', 'Platforms & Wedges']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Necklaces', 'Pendant Necklaces']
# ['Clothing, Shoes & Jewelry', 'Costumes & Accessories', 'Kids & Baby', 'Girls', 'Wigs']
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Hats & Caps', 'Skullies & Beanies']
# ['Clothing, Shoes & Jewelry', 'Luggage & Travel Gear', 'Backpacks', "Kids' Backpacks"]
# ['Clothing, Shoes & Jewelry', 'Men', 'Accessories', 'Ties, Cummerbunds & Pocket Squares', 'Tie Sets']
# ['Clothing, Shoes & Jewelry', 'Boot Shop', 'Women', 'Fashion', 'Riding']
# ['Clothing, Shoes & Jewelry', 'Women', 'Watches', 'Wrist Watches']
# ['Clothing, Shoes & Jewelry', 'Women', 'Uniforms, Work & Safety', 'Clothing', 'Medical', 'Scrub Tops']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Lingerie, Sleep & Lounge', 'Lingerie', 'Camisoles & Tanks']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Pants', 'Casual']
# ['Clothing, Shoes & Jewelry', 'Men', 'Accessories', 'Gloves & Mittens', 'Cold Weather Gloves']
# ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', 'Athletic', 'Running', 'Road Running']
# ['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories', 'Jewelry Accessories', 'Jewelry Boxes & Organizers']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals', 'Platforms & Wedges']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Men', 'Shirts', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Athletic', 'Sport Sandals & Slides']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Women', 'Tops & Tees', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Swimsuits & Cover Ups', 'Bikinis', 'Sets']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Bracelets', 'Wrap']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Necklaces', 'Pendant Necklaces']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Athletic', 'Walking']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Sandals', 'Slides']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Shorts', 'Flat Front']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Fashion Hoodies & Sweatshirts']
# ['Clothing, Shoes & Jewelry', 'Westlake']
# ['Clothing, Shoes & Jewelry', 'Westlake']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Athletic Socks']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Active', 'Athletic Socks']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Rings', 'Statement']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Jackets & Coats', 'Trench & Rain']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Dresses', 'Casual']
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Hats & Caps', 'Cold Weather Headbands']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Fashion Sneakers']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Tops, Tees & Blouses', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Athletic', 'Water Shoes']
# ['Clothing, Shoes & Jewelry', 'Men', 'Jewelry', 'Necklaces']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Lingerie, Sleep & Lounge', 'Lingerie', 'Bras', 'Everyday Bras']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Pumps']
# ['Clothing, Shoes & Jewelry', 'Sport Specific Clothing', 'Running', 'Women', 'Socks']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Men', 'Shirts', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Fashion Hoodies & Sweatshirts']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Women', 'Tops & Tees', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Men', 'Shirts', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Dresses']
# ['Clothing, Shoes & Jewelry', 'Baby', 'Baby Boys', 'Clothing', 'Bodysuits']
# ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Flats']
# ['Clothing, Shoes & Jewelry', 'Girls', 'Clothing', 'Dresses']
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Special Occasion Accessories', 'Bridal Accessories']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Dresses']
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Hats & Caps', 'Skullies & Beanies']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Dresses', 'Casual']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Athletic Socks']
# ['Clothing, Shoes & Jewelry', 'Men', 'Accessories', 'Wallets, Card Cases & Money Organizers', 'Wallets']
# ['Clothing, Shoes & Jewelry', 'Women', 'Jewelry', 'Earrings', 'Cuffs & Wraps']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Jumpsuits, Rompers & Overalls', 'Rompers']
# ['Clothing, Shoes & Jewelry', 'Men', 'Watches', 'Wrist Watches']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Active Sweatshirts']
# ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Tops, Tees & Blouses', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Sport Specific Clothing', 'Yoga', 'Women', 'Socks']
# ['Clothing, Shoes & Jewelry', 'Women', 'Accessories', 'Hats & Caps', 'Headbands']
# ['Clothing, Shoes & Jewelry', 'Novelty & More', 'Clothing', 'Novelty', 'Men', 'Shirts', 'T-Shirts']
# ['Clothing, Shoes & Jewelry', 'Men', 'Clothing', 'Active', 'Track & Active Jackets']
# ['Clothing, Shoes & Jewelry', 'Luggage & Travel Gear', 'Backpacks', 'Casual Daypacks']
# ['Clothing, Shoes & Jewelry', 'Girls', 'Clothing', 'Fashion Hoodies & Sweatshirts']

# %%
#jsonl.gz file (meta)
watch_meta = {}

def is_watch_product(product):
    #'watch' in main_category
    main_cat=(product.get("main_category") or "").lower()
    if "watch" in main_cat:
        return True

    #'watch' in categories (lowest level; end of list)
    categories = product.get("categories", [])
    if isinstance(categories, list) and categories:
        last_category = categories[-1]
        if "watch" in last_category.lower():
            return True

with gzip.open('meta_Clothing_Shoes_and_Jewelry.jsonl.gz', "rt", encoding="utf-8") as meta_file:
    for line in tqdm(meta_file, desc="Filtering metadata"):
        product=json.loads(line) #loading product meta data
        if is_watch_product(product):
            parent_asin=product.get("parent_asin")
            if parent_asin:
                watch_meta[parent_asin]=product  

print(f'{len(watch_meta)} watch-related products.')
# Out:
# Filtering metadata: 7218481it [01:31, 78969.00it/s]
# 173763 watch-related products.

# %%
#opening jsonl.gz file (reviews)
reviews=[]
watch_parent_asins=set(watch_meta.keys()) #create a set that has watch parent asins; set to help processing speed

with gzip.open('Clothing_Shoes_and_Jewelry.jsonl.gz', "rt", encoding="utf-8") as f:
    for i, line in enumerate(f):
        review=json.loads(line)
        if review.get("parent_asin") in watch_parent_asins:
            reviews.append(review)

# %%
#combining reviews and meta information
full_ds=[]

for review in reviews:
    parent_asin=review.get("parent_asin")
    product_info=watch_meta.get(parent_asin)

    if product_info:
        #combine review columns + meta columns
        merged={**{f"review_{k}": v for k, v in review.items()},
                  **{f"meta_{k}": v for k, v in product_info.items()}}
        full_ds.append(merged)

# %%
#csv; created a new file so previous steps do not need to be repeated

#keys
all_keys = set()
for row in full_ds:
    all_keys.update(row.keys())

fieldnames=sorted(all_keys)

with open('amazon_watch_reviews.csv', "w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(full_ds)
    print(f"{len(full_ds)} rows in CSV.") #result = 7.99 gb csv file
# Out:
# 2015895 rows in CSV.

# %%
#loading as pandas dataframe
df=pd.read_csv('amazon_watch_reviews.csv')
df.head()
# Out:
# /var/folders/rs/56dc52116fdc6_zgn1vcs_fr0000gp/T/ipykernel_15354/709879066.py:2: DtypeWarning: Columns (0,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('amazon_watch_reviews.csv')
#   meta_author  meta_average_rating  meta_bought_together  \
# 0         NaN                  4.5                   NaN
# 1         NaN                  4.4                   NaN
# 2         NaN                  4.7                   NaN
# 3         NaN                  4.7                   NaN
# 4         NaN                  4.2                   NaN
#
#                                      meta_categories  \
# 0  ['Clothing, Shoes & Jewelry', 'Women', 'Watche...
# 1  ['Clothing, Shoes & Jewelry', 'Women', 'Watches']
# 2  ['Clothing, Shoes & Jewelry', 'Men', 'Watches'...
# 3  ['Clothing, Shoes & Jewelry', 'Women', 'Watche...
# 4  ['Clothing, Shoes & Jewelry', 'Women', 'Watche...
#
#                                     meta_description  \
# 0  ['Speidel Petite Scrub Watch for Nurse, Doctor...
# 1  ["The Casio Women's Digital White Resin Strap ...
# 2                                                 []
# 3                                                 []
# 4  ['Peugeot watches have been redefining fashion...
#
#                                         meta_details  \
# 0  {'Product Dimensions': '7.1 x 1.1 x 0.31 inche...
# 1  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 2  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 3  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 4  {'Is Discontinued By Manufacturer': 'No', 'Pac...
#
#                                        meta_features  \
# 0  ['PERFECT FOR NURSES, DOCTORS, EMT, SURGEONS &...
# 1  ['Imported', 'Round sport watch featuring pink...
# 2  ['Timeless styling that effortlessly takes you...
# 3  ['Timeless styling that effortlessly takes you...
# 4  ['Imported', "The perfect women's watch for sm...
#
#                                          meta_images meta_main_category  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...     AMAZON FASHION
# 1  [{'thumb': 'https://m.media-amazon.com/images/...     AMAZON FASHION
# 2  [{'thumb': 'https://m.media-amazon.com/images/...     AMAZON FASHION
# 3  [{'thumb': 'https://m.media-amazon.com/images/...     AMAZON FASHION
# 4  [{'thumb': 'https://m.media-amazon.com/images/...     AMAZON FASHION
#
#   meta_parent_asin  ... review_asin  review_helpful_vote review_images  \
# 0       B07HJ84J9M  ...  B07HJ9DJGQ                    0            []
# 1       B001UHMUXC  ...  B001UHMUXC                    0            []
# 2       B0BYT41CVB  ...  B00PXVUKBK                    0            []
# 3       B09ZL4W5T8  ...  B004JKDLVW                    0            []
# 4       B01D8MNCPG  ...  B0016OOXMA                    1            []
#
#   review_parent_asin review_rating  \
# 0         B07HJ84J9M           5.0
# 1         B001UHMUXC           5.0
# 2         B0BYT41CVB           5.0
# 3         B09ZL4W5T8           5.0
# 4         B01D8MNCPG           5.0
#
#                                          review_text review_timestamp  \
# 0  Love this watch! It's perfectly petite! It's r...    1624587865782
# 1            Does its job nicely for work - Nursing!    1452650548000
# 2  Got this for my boyfriend for Christmas, he lo...    1578527465894
# 3  I love this watch and wear it often, absolutel...    1535058677377
# 4  I bought this watch to wear to an interview, a...    1481817389000
#
#                 review_title                review_user_id  \
# 0     Great watch for nurses  AGGZ357AO26RQZVRLGU4D4N52DZQ
# 1                 Five Stars  AGKASBHYZPGTEPO6LWZPVJWB2BVA
# 2      Nice watch, good gift  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ
# 3    pretty watch, well made  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ
# 4  and it's perfect for that  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ
#
#   review_verified_purchase
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 26 columns]

# %%
#checking that file is capturing mainly watch/watch related content
df['meta_categories'].unique()
# Out:
# array(["['Clothing, Shoes & Jewelry', 'Women', 'Watches', 'Wrist Watches']",
#        "['Clothing, Shoes & Jewelry', 'Women', 'Watches']",
#        "['Clothing, Shoes & Jewelry', 'Men', 'Watches', 'Wrist Watches']",
#        "['Clothing, Shoes & Jewelry', 'Women', 'Watches', 'Watch Bands']",
#        "['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories', 'Watch Accessories', 'Pocket Watch Chains']",
#        "['Clothing, Shoes & Jewelry', 'Men', 'Watches', 'Watch Bands']",
#        "['Clothing, Shoes & Jewelry', 'Novelty & More', 'Watches']",
#        "['Clothing, Shoes & Jewelry', 'Boys', 'Watches', 'Wrist Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Watches Under $50"]',
#        "['Clothing, Shoes & Jewelry', 'Jewelry & Watches Outlet']",
#        "['Clothing, Shoes & Jewelry', 'Men', 'Watches', 'Smartwatches']",
#        "['Clothing, Shoes & Jewelry', 'Girls', 'Watches', 'Wrist Watches']",
#        "['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories', 'Watch Accessories', 'Watch Winders']",
#        "['Clothing, Shoes & Jewelry', 'Women', 'Watches', 'Smartwatches']",
#        "['Clothing, Shoes & Jewelry', 'Men', 'Watches', 'Pocket Watches']",
#        "['Clothing, Shoes & Jewelry', 'Smart Watches']",
#        "['Clothing, Shoes & Jewelry', 'Must-Have Bracelet Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Watch Accessories"]',
#        "['Clothing, Shoes & Jewelry', 'Marc Jacobs Watches']",
#        "['Clothing, Shoes & Jewelry', 'Fashion Watches']",
#        "['Clothing, Shoes & Jewelry', 'Sport Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Up to 70% Off Men\'s Casual Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Save up to 50% on Select Watches']",
#        "['Clothing, Shoes & Jewelry', 'Women', 'Watches', 'Pocket Watches']",
#        "['Clothing, Shoes & Jewelry', 'Men', 'Watches']",
#        "['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories', 'Watch Accessories']",
#        '[\'Clothing, Shoes & Jewelry\', "Women\'s watches under $65"]',
#        "['Clothing, Shoes & Jewelry', 'Timex Watches: Gifts Under $50']",
#        "['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories']",
#        "['Clothing, Shoes & Jewelry', 'Save up to 50% on select watches from Citizen, Casio, and Bulova']",
#        "['Clothing, Shoes & Jewelry', 'Up to 25% Off Select Jewelry & Watches']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Leather Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Women\'s Leather Watches for Spring"]',
#        "['Clothing, Shoes & Jewelry', 'Boys', 'Watches', 'Pocket Watches']",
#        "['Clothing, Shoes & Jewelry', 'Sporty Chic Gifts for Her: Smart Watches']",
#        "['Clothing, Shoes & Jewelry', 'Up to 60% off Best Sellers from Top Watch Brands']",
#        '[\'Clothing, Shoes & Jewelry\', "Editors\' Picks: Bold Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Smartwatches']",
#        "['Clothing, Shoes & Jewelry', 'Shoe, Jewelry & Watch Accessories', 'Watch Accessories', 'Watch Bands']",
#        "['Clothing, Shoes & Jewelry', 'Girls', 'Watches']",
#        "['Clothing, Shoes & Jewelry', 'Boys', 'Watches']",
#        "['Clothing, Shoes & Jewelry', 'Take 20% Off Watches for Men & Women']",
#        "['Clothing, Shoes & Jewelry', 'Girls', 'Watches', 'Watch Bands']",
#        "['Clothing, Shoes & Jewelry', 'Watches, Jewelry & More for Dad']",
#        "['Clothing, Shoes & Jewelry', 'Casual & Classic Leather Watches']",
#        "['Clothing, Shoes & Jewelry', 'Watch Sets We Love']",
#        "['Clothing, Shoes & Jewelry', 'Day 12: Take 40% Off Select Timex Watches']",
#        "['Clothing, Shoes & Jewelry', 'Up to 75% Off Select Watches']",
#        "['Clothing, Shoes & Jewelry', 'Up to 20% Off Select Jewelry & Watches']",
#        "['Clothing, Shoes & Jewelry', 'Nike Watches']",
#        "['Clothing, Shoes & Jewelry', 'Seiko Watches']",
#        "['Clothing, Shoes & Jewelry', '20% Off Jewelry & Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Our Favorite Women\'s Watch Sets"]',
#        "['Clothing, Shoes & Jewelry', 'Watches & Jewelry Starting at $100']",
#        "['Clothing, Shoes & Jewelry', 'All Gender Watches']",
#        "['Clothing, Shoes & Jewelry', 'All-New Watches']",
#        "['Clothing, Shoes & Jewelry', 'Free One-Day Shipping on Watches']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Watch Gift Sets']",
#        "['Clothing, Shoes & Jewelry', 'Top Watch Gifts']",
#        "['Clothing, Shoes & Jewelry', 'Military-Inspired Hues: Casual Watches']",
#        "['Clothing, Shoes & Jewelry', 'Boys', 'Watches', 'Watch Bands']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Action Sport Watches"]',
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Metal Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Free One-Day Shipping on Jewelry, Watches, & More']",
#        "['Clothing, Shoes & Jewelry', 'Up to 50% Off Watches for Dad']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Retro Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Kids\' Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Titan Watches']",
#        "['Clothing, Shoes & Jewelry', 'Take 20% Off Select Watches']",
#        "['Clothing, Shoes & Jewelry', 'Up to 50% Off Top Fashion Smartwatches']",
#        "['Clothing, Shoes & Jewelry', 'Summer Picks: Men’s Watches']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Dress Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Casual Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Smartwatches and Hybrids']",
#        "['Clothing, Shoes & Jewelry', 'Swatch Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Up to 70% Off Women\'s Fashion Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Smart Watches for All']",
#        '[\'Clothing, Shoes & Jewelry\', "Women\'s Luxury Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Longines Watches']",
#        "['Clothing, Shoes & Jewelry', 'Classics with a Twist: Jewelry & Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "A Smarter Women\'s Smartwatch"]',
#        "['Clothing, Shoes & Jewelry', 'Take 20% Off Watches']",
#        "['Clothing, Shoes & Jewelry', 'Deal of the Day | Save on Best Sellers from Top Watch Brands']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Minimalist Watches']",
#        "['Clothing, Shoes & Jewelry', 'LEGO® Watches']",
#        "['Clothing, Shoes & Jewelry', 'Everyday Watches']",
#        "['Clothing, Shoes & Jewelry', 'Fossil Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Women\'s Timeless Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Citizen Watches: Chronograph']",
#        "['Clothing, Shoes & Jewelry', 'Jewelry & Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Fossil: Men\'s Dress Watches"]',
#        '[\'Clothing, Shoes & Jewelry\', "Casual Leather Women\'s Watches"]',
#        '[\'Clothing, Shoes & Jewelry\', "Father\'s Day Watch Gifts"]',
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Classic Women’s Watches']",
#        "['Clothing, Shoes & Jewelry', 'Stocking Stuffers: Jewelry & Watches']",
#        "['Clothing, Shoes & Jewelry', 'Gold-Tone Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Summer-Ready Style: Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Watches Gifts for Mom']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Mixed-Metal Watches"]',
#        '[\'Clothing, Shoes & Jewelry\', "Save 30% on MVMT Men\'s and Women\'s Watches"]',
#        '[\'Clothing, Shoes & Jewelry\', "Fossil: Women\'s Rose-Gold Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Collectible Watches']",
#        "['Clothing, Shoes & Jewelry', 'Up to 75% Off Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Women\'s Smart-Tech Jewelry and Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Our Favorite Black & White Watches']",
#        "['Clothing, Shoes & Jewelry', 'Victorinox Swiss Army Watches']",
#        "['Clothing, Shoes & Jewelry', 'Colored-Dial Watches']",
#        "['Clothing, Shoes & Jewelry', 'Oris Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Fall Shopping List: Watch Update"]',
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Slim-Profile Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Men\'s Classic Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Hamilton Watches']",
#        "['Clothing, Shoes & Jewelry', 'Jewelry and watches for Mom']",
#        "['Clothing, Shoes & Jewelry', 'adidas Watches']",
#        "['Clothing, Shoes & Jewelry', 'Girls', 'Watches', 'Pocket Watches']",
#        "['Clothing, Shoes & Jewelry', 'The High-Shine Watch']",
#        "['Clothing, Shoes & Jewelry', 'Must-Have Metal Watches']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Leather Watches']",
#        "['Clothing, Shoes & Jewelry', 'Ornate Opulence: Elegantly Adorned Watches']",
#        "['Clothing, Shoes & Jewelry', 'Navy Watches for Her']",
#        "['Clothing, Shoes & Jewelry', 'Up to 50% off New & Trending Watches for Spring']",
#        "['Clothing, Shoes & Jewelry', '30% or More Off Multi-Function Watches']",
#        "['Clothing, Shoes & Jewelry', 'Deal Of The Day | 50% Off Golf Clothing, Shoes, Watches & More']",
#        "['Clothing, Shoes & Jewelry', 'Must-See Markdowns on Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Up to 70% Off Women\'s Casual Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Red and Rose Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Women\'s Mesh-Metal Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Watches Green Light ASINs']",
#        '[\'Clothing, Shoes & Jewelry\', "Up to 40% off Watches for Father\'s Day"]',
#        "['Clothing, Shoes & Jewelry', 'Polished Leather Watches']",
#        "['Clothing, Shoes & Jewelry', 'Michele Watches']",
#        "['Clothing, Shoes & Jewelry', 'Editors’ Picks: Men’s Navy Watches']",
#        "['Clothing, Shoes & Jewelry', 'Watches for the Family']",
#        '[\'Clothing, Shoes & Jewelry\', "New Year, New Gear: Men\'s Sport Watches"]',
#        "['Clothing, Shoes & Jewelry', 'DKNY Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Mother\'s Day Watch Gifts"]',
#        "['Clothing, Shoes & Jewelry', 'Must-Have Sport Watches']",
#        "['Clothing, Shoes & Jewelry', '50% or More Off Bracelet Watches']",
#        "['Clothing, Shoes & Jewelry', 'Breitling Watches']",
#        "['Clothing, Shoes & Jewelry', 'Our Favorite Mini Watches']",
#        "['Clothing, Shoes & Jewelry', 'Cartier Watches']",
#        '[\'Clothing, Shoes & Jewelry\', "Classic Men\'s Watches"]',
#        '[\'Clothing, Shoes & Jewelry\', "Mother\'s Day Gifts- Jewelry & Watches"]',
#        "['Clothing, Shoes & Jewelry', 'Rolex Watches']"], dtype=object)

# %%
df.columns
# Out:
# Index(['meta_author', 'meta_average_rating', 'meta_bought_together',
#        'meta_categories', 'meta_description', 'meta_details', 'meta_features',
#        'meta_images', 'meta_main_category', 'meta_parent_asin', 'meta_price',
#        'meta_rating_number', 'meta_store', 'meta_subtitle', 'meta_title',
#        'meta_videos', 'review_asin', 'review_helpful_vote', 'review_images',
#        'review_parent_asin', 'review_rating', 'review_text',
#        'review_timestamp', 'review_title', 'review_user_id',
#        'review_verified_purchase'],
#       dtype='object')

# %% [markdown]
# Want to keep the following columns
# * meta_average_rating
# * meta_description
# * meta_details
# * meta_features
# * meta_price
# * meta_title
# * meta_subtitle
# * review_rating
# * review_text
# * review_title
# * review_verified_purchase

# %%
df=df[['meta_title','meta_subtitle','meta_average_rating','meta_description','meta_details','meta_features','meta_price',
                    'review_rating','review_title','review_text','review_verified_purchase']]
df.head()
# Out:
#                                           meta_title meta_subtitle  \
# 0  Speidel Petite Scrub Watch™ for Nurse, Doctors...           NaN
# 1  Casio Women's LW200-7AV Digital Watch with Whi...           NaN
# 2  Citizen Men's Classic Eco-Drive Leather Strap ...           NaN
# 3  Citizen Eco-Drive Chandler Womens Watch, Stain...           NaN
# 4  Peugeot Women's Petite Round Wrist Watch with ...           NaN
#
#    meta_average_rating                                   meta_description  \
# 0                  4.5  ['Speidel Petite Scrub Watch for Nurse, Doctor...
# 1                  4.4  ["The Casio Women's Digital White Resin Strap ...
# 2                  4.7                                                 []
# 3                  4.7                                                 []
# 4                  4.2  ['Peugeot watches have been redefining fashion...
#
#                                         meta_details  \
# 0  {'Product Dimensions': '7.1 x 1.1 x 0.31 inche...
# 1  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 2  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 3  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 4  {'Is Discontinued By Manufacturer': 'No', 'Pac...
#
#                                        meta_features meta_price  \
# 0  ['PERFECT FOR NURSES, DOCTORS, EMT, SURGEONS &...       49.0
# 1  ['Imported', 'Round sport watch featuring pink...      19.42
# 2  ['Timeless styling that effortlessly takes you...      163.9
# 3  ['Timeless styling that effortlessly takes you...     182.96
# 4  ['Imported', "The perfect women's watch for sm...      52.99
#
#    review_rating               review_title  \
# 0            5.0     Great watch for nurses
# 1            5.0                 Five Stars
# 2            5.0      Nice watch, good gift
# 3            5.0    pretty watch, well made
# 4            5.0  and it's perfect for that
#
#                                          review_text  review_verified_purchase
# 0  Love this watch! It's perfectly petite! It's r...                      True
# 1            Does its job nicely for work - Nursing!                      True
# 2  Got this for my boyfriend for Christmas, he lo...                      True
# 3  I love this watch and wear it often, absolutel...                      True
# 4  I bought this watch to wear to an interview, a...                      True

# %%
df.isnull().sum()
# Out:
# meta_title                      230
# meta_subtitle               2015422
# meta_average_rating               0
# meta_description                  0
# meta_details                      0
# meta_features                     0
# meta_price                   956518
# review_rating                     0
# review_title                    492
# review_text                    1009
# review_verified_purchase          0
# dtype: int64

# %%
#double checking that there are less unique titles than rows (watches should have multiple reviews; thus title values should repeat)
len(df['meta_title'].unique())
# Out:
# 158899

# %%
#grouping reviews by watch model
reviews_grouped=df.groupby("meta_title")["review_text"].apply(list).reset_index()
reviews_grouped['review_text'][0]
# Out:
# ['Cutest watch ever , bought for myself, little small but i can still wear. Love it.']

# %%
reviews_grouped['review_text'][1]
# Out:
# ['Two kids toy way too expensive for that']

# %%
reviews_grouped['review_text'][2]
# Out:
# ["I really like this watch. It is very quirky. It is mechanical and must be wound daily. It is fairly accurate. Setting the date is a hassle but there are ways to do it(see YouTube). It is bullet-proof. Not Casio bullet-proof but its tough. Put it on a NATO strap and its good to go.<br />3 stars because I really haven't had it long enough, but I really like it.<br />Prob gonna get an Amphibian next.",
#  'I like this as I do all 8 V/Bostoc of the company. A tank of a watch !',
#  "Very nice watch, but it doesn't work properly",
#  "I love the watch. It's quirky time-piece that catches the eyes of many. The story is a great one, especially for a sub-$100 watch. I had to change the strap because it was utter garbage but once the strap was changed to a quality leather, it wears great. I would recommend this to anyone who wants a watch with a story but is on a budget.",
#  "Beautiful watch didn't know its manual winding nice watch and good seller thanks",
#  'Awesome watch, shipping was much faster than originally estimated. I am very happy with this purchase.',
#  'This watch is exactly what you’d expect of a Soviet era Russian watch: indestructible, unrefined, quirky, and cheap. And after replacing the awful leather strap with an aftermarket bracelet, I understand why so many people love them. The watch has loads of character and doesn’t try to pretend to me something it’s not.<br />Setting the time and date can be a pain with the wobbly by design crown, but the solution itself for protecting the movement is genius.<br />If you do get this watch, just budget another $20-$35 for a nicer strap or bracelet. The SKX bezel has a different gloss level than the dial, but adds to the character of the watch.<br />It’s been keeping good time at +/- 5sec a day. It’s in line with my other automatics and hand-winders.<br /><br />It’s not the best watch, but it’s fun and rightfully earns its place in my collection. You could do much worse for a beater watch than this.',
#  'El articulo venia dañado, el reloj no da cuerda',
#  'No me gustó',
#  'Very nice watch']

# %%
len(reviews_grouped)
# Out:
# 158898
